# %%
import cv2

# %%
im = cv2.imread('Highway.jpg')

image_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(im)

# %%
plt.imshow(image_rgb + 123)

# %%
import numpy as np
import torch
image =  torch.from_numpy(image_rgb)
image.shape
# Out:
# torch.Size([398, 612, 3])

# %%
plt.imshow(image +123)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=612x398>

# %%
torch.exp(torch.Tensor([0.1]))
# Out:
# tensor([1.1052])

# %%
import torch
from torchvision import transforms
from PIL import Image

# Load the image using PIL
image = Image.open("Highway.jpg").convert("RGB")  # Ensure it's in RGB format

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=612x398>

# %%
# Define the preprocessing transformations
transform = transforms.Compose([ 
    transforms.ToTensor()        # Convert the image to a PyTorch tensor
])

# %%
# Apply the transformations to the image
image_tensor = transform(image)


# Add a batch dimension (needed for models)
image_tensor = image_tensor.unsqueeze(0)  # Shape: (1, C, H, W)

# %%
image_tensor.shape
# Out:
# torch.Size([3, 398, 612])

# %%
imo = image_tensor.permute(1,2,0)

# %%
imo.shape
# Out:
# torch.Size([398, 612, 3])

# %%
plt.imshow(imo)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=612x398>

# %%
import torch.nn as nn

# %%
imo.shape
# Out:
# torch.Size([398, 612, 3])

# %%
model = nn.Conv2d(3, 3, kernel_size=1, stride=1, bias=False)

# %%
x = model(image_tensor)

# %%
x
# Out:
# tensor([[[-0.3796, -0.3818, -0.3835,  ..., -0.2812, -0.2880, -0.2944],
#          [-0.3817, -0.3785, -0.3834,  ..., -0.3052, -0.3115, -0.3178],
#          [-0.3784, -0.3806, -0.3787,  ..., -0.3287, -0.3328, -0.3370],
#          ...,
#          [-0.1281, -0.1281, -0.1302,  ..., -0.1598, -0.1577, -0.1535],
#          [-0.1260, -0.1281, -0.1281,  ..., -0.1598, -0.1577, -0.1535],
#          [-0.1281, -0.1281, -0.1302,  ..., -0.1619, -0.1577, -0.1556]],
#
#         [[-0.1136, -0.1151, -0.1139,  ..., -0.1195, -0.1206, -0.1228],
#          [-0.1139, -0.1108, -0.1127,  ..., -0.1250, -0.1260, -0.1283],
#          [-0.1095, -0.1111, -0.1081,  ..., -0.1316, -0.1311, -0.1318],
#          ...,
#          [-0.0395, -0.0395, -0.0399,  ..., -0.0201, -0.0198, -0.0191],
#          [-0.0392, -0.0395, -0.0395,  ..., -0.0201, -0.0198, -0.0191],
#          [-0.0395, -0.0395, -0.0399,  ..., -0.0205, -0.0198, -0.0194]],
#
#         [[-0.0318, -0.0344, -0.0397,  ..., -0.0304, -0.0342, -0.0377],
# ...

# %%
x.shape
# Out:
# torch.Size([3, 398, 612])

# %%
x = x.permute(1,2,0)

# %%
plt.imshow(x.detach())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import numpy as np

import numpy as np

arr = np.array([10, 20, 30, 40, 50])
x = [1, 2, 3, 0, 4]  # New index order

arr = arr[x]

# %%
arr
# Out:
# array([20, 30, 40, 10, 50])
