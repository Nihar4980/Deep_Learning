# %%
# Dataset - https://www.kaggle.com/datasets/salader/dogs-vs-cats
# go to your profile
# Go to accounts
# click on create new api token - a jason file will be download
# Upload that file in google-colab
# run two command prefetch jason file
# download datasets command

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d salader/dogs-vs-cats
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading dogs-vs-cats.zip to /content
# 100% 1.06G/1.06G [00:05<00:00, 181MB/s]
# 100% 1.06G/1.06G [00:05<00:00, 202MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/dogs-vs-cats.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
from keras.applications.vgg16 import VGG16

# %%
# generators
train_ds = keras.utils.image_dataset_from_directory(
    directory = '/content/train',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(224,224)
)

validation_ds = keras.utils.image_dataset_from_directory(
    directory = '/content/test',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(224,224)
)
# Out:
# Found 20000 files belonging to 2 classes.
# Found 5000 files belonging to 2 classes.

# %%
# Normalize
def process(image,label):
    image = tf.cast(image/255. ,tf.float32)
    return image,label

train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
# create CNN model

model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding='same',activation='relu',input_shape=(224,224,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(128,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(256,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Flatten())

model.add(Dense(256,activation='relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(16,activation='relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(8,activation='relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  batch_normalization (BatchN  (None, 224, 224, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  batch_normalization_1 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 28, 28, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 256)               12845312
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  batch_normalization_7 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dropout_4 (Dropout)         (None, 16)                0
#
#  batch_normalization_8 (Batc  (None, 16)               64
#  hNormalization)
#
#  dense_5 (Dense)             (None, 8)                 136
#
#  dropout_5 (Dropout)         (None, 8)                 0
#
#  batch_normalization_9 (Batc  (None, 8)                32
#  hNormalization)
#
#  dense_6 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 13,281,569
# Trainable params: 13,279,601
# Non-trainable params: 1,968
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
import time
start = time.time()
history = model.fit(train_ds,epochs=10,validation_data=validation_ds)
end = time.time() - start
# Out:
# Epoch 1/10
# 625/625 [==============================] - 82s 101ms/step - loss: 0.6524 - accuracy: 0.6212 - val_loss: 0.6415 - val_accuracy: 0.6320
# Epoch 2/10
# 625/625 [==============================] - 63s 99ms/step - loss: 0.5420 - accuracy: 0.7273 - val_loss: 0.5208 - val_accuracy: 0.7506
# Epoch 3/10
# 625/625 [==============================] - 64s 101ms/step - loss: 0.4625 - accuracy: 0.7863 - val_loss: 0.7867 - val_accuracy: 0.5652
# Epoch 4/10
# 625/625 [==============================] - 63s 101ms/step - loss: 0.3901 - accuracy: 0.8309 - val_loss: 0.5136 - val_accuracy: 0.7644
# Epoch 5/10
# 625/625 [==============================] - 60s 96ms/step - loss: 0.3146 - accuracy: 0.8692 - val_loss: 0.4128 - val_accuracy: 0.8142
# Epoch 6/10
# 625/625 [==============================] - 58s 93ms/step - loss: 0.2464 - accuracy: 0.8997 - val_loss: 0.2994 - val_accuracy: 0.8744
# Epoch 7/10
# 625/625 [==============================] - 63s 100ms/step - loss: 0.1929 - accuracy: 0.9232 - val_loss: 0.4098 - val_accuracy: 0.8146
# Epoch 8/10
# 625/625 [==============================] - 62s 98ms/step - loss: 0.1679 - accuracy: 0.9330 - val_loss: 0.3140 - val_accuracy: 0.8770
# Epoch 9/10
# 625/625 [==============================] - 60s 96ms/step - loss: 0.1291 - accuracy: 0.9517 - val_loss: 0.4536 - val_accuracy: 0.8470
# Epoch 10/10
# 625/625 [==============================] - 62s 99ms/step - loss: 0.1497 - accuracy: 0.9452 - val_loss: 0.4239 - val_accuracy: 0.8594

# %%
print(end)
# Out:
# 703.7639331817627

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
# ways to reduce overfitting

# Add more data
# Data Augmentation -> next video
# L1/L2 Regularizer
# Dropout
# Batch Norm
# Reduce complexity

# %%
import cv2

# %%
test_img = cv2.imread('/content/test/cats/cat.10.jpg')

# %%
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (499, 489, 3)

# %%
test_img = cv2.resize(test_img,(224,224))

# %%
test_input = test_img.reshape((1,224,224,3))

# %%
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 372ms/step
# array([[0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/test/dogs/dog.100.jpg')

# %%
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(224,224))
test_input = test_img.reshape((1,224,224,3))

# %%
plt.imshow(test_img)

# %%
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# array([[1.]], dtype=float32)

# %%
# Feature Extraction

# %%
conv_base = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# %%
model = Sequential()

model.add(conv_base)
model.add(Flatten())

model.add(Dense(256,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  dense_11 (Dense)            (None, 256)               6422784
#
#  dense_12 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 21,137,729
# Trainable params: 21,137,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
conv_base.trainable = False

# %%
model = Sequential()

model.add(conv_base)
model.add(Flatten())

model.add(Dense(256,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_4 (Flatten)         (None, 25088)             0
#
#  dense_13 (Dense)            (None, 256)               6422784
#
#  dense_14 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(train_ds,epochs=10,validation_data=validation_ds)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 115s 175ms/step - loss: 0.2536 - accuracy: 0.9023 - val_loss: 0.1662 - val_accuracy: 0.9316
# Epoch 2/10
# 625/625 [==============================] - 128s 204ms/step - loss: 0.1309 - accuracy: 0.9485 - val_loss: 0.1600 - val_accuracy: 0.9350
# Epoch 3/10
# 625/625 [==============================] - 128s 204ms/step - loss: 0.1030 - accuracy: 0.9589 - val_loss: 0.1827 - val_accuracy: 0.9286
# Epoch 4/10
# 625/625 [==============================] - 108s 172ms/step - loss: 0.0761 - accuracy: 0.9707 - val_loss: 0.2245 - val_accuracy: 0.9232
# Epoch 5/10
# 625/625 [==============================] - 108s 172ms/step - loss: 0.0634 - accuracy: 0.9761 - val_loss: 0.2023 - val_accuracy: 0.9300
# Epoch 6/10
# 625/625 [==============================] - 128s 204ms/step - loss: 0.0483 - accuracy: 0.9829 - val_loss: 0.2598 - val_accuracy: 0.9190
# Epoch 7/10
# 625/625 [==============================] - 108s 173ms/step - loss: 0.0446 - accuracy: 0.9823 - val_loss: 0.2308 - val_accuracy: 0.9260
# Epoch 8/10
# 625/625 [==============================] - 127s 203ms/step - loss: 0.0416 - accuracy: 0.9841 - val_loss: 0.2719 - val_accuracy: 0.9314
# Epoch 9/10
# 625/625 [==============================] - 108s 173ms/step - loss: 0.0192 - accuracy: 0.9936 - val_loss: 0.2772 - val_accuracy: 0.9316
# Epoch 10/10
# 625/625 [==============================] - 109s 174ms/step - loss: 0.0329 - accuracy: 0.9882 - val_loss: 0.2889 - val_accuracy: 0.9266

# %%
plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
# Data Augmented
from keras.preprocessing.image import ImageDataGenerator

# %%
batch_size = 32

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    '/content/train',
    target_size = (224,224),
    batch_size = batch_size,
    class_mode= 'binary')

validation_generator = validation_datagen.flow_from_directory(
    '/content/test',
    target_size = (224,224),
    batch_size = batch_size,
    class_mode= 'binary')
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %%
conv_base = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

conv_base.trainable = False

model = Sequential()

model.add(conv_base)
model.add(Flatten())

model.add(Dense(256,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 25088)             0
#
#  dense_15 (Dense)            (None, 256)               6422784
#
#  dense_16 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit_generator(train_generator,epochs=10,validation_data=validation_generator)
# Out:
# <ipython-input-54-204d5da4b169>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,epochs=10,validation_data=validation_generator)
# Epoch 1/10
# 625/625 [==============================] - 310s 493ms/step - loss: 0.2905 - accuracy: 0.8866 - val_loss: 0.1616 - val_accuracy: 0.9334
# Epoch 2/10
# 625/625 [==============================] - 311s 497ms/step - loss: 0.1933 - accuracy: 0.9184 - val_loss: 0.1556 - val_accuracy: 0.9358
# Epoch 3/10
# 625/625 [==============================] - 308s 492ms/step - loss: 0.1650 - accuracy: 0.9311 - val_loss: 0.1474 - val_accuracy: 0.9374
# Epoch 4/10
# 625/625 [==============================] - 324s 518ms/step - loss: 0.1689 - accuracy: 0.9319 - val_loss: 0.1862 - val_accuracy: 0.9232
# Epoch 5/10
# 625/625 [==============================] - 331s 530ms/step - loss: 0.1506 - accuracy: 0.9391 - val_loss: 0.1433 - val_accuracy: 0.9400
# Epoch 6/10
# 625/625 [==============================] - 300s 480ms/step - loss: 0.1443 - accuracy: 0.9402 - val_loss: 0.1485 - val_accuracy: 0.9392
# Epoch 7/10
# 625/625 [==============================] - 296s 473ms/step - loss: 0.1277 - accuracy: 0.9485 - val_loss: 0.1831 - val_accuracy: 0.9294
# Epoch 8/10
# 625/625 [==============================] - 298s 476ms/step - loss: 0.1273 - accuracy: 0.9463 - val_loss: 0.1553 - val_accuracy: 0.9352
# Epoch 9/10
# 625/625 [==============================] - 318s 509ms/step - loss: 0.1210 - accuracy: 0.9513 - val_loss: 0.1470 - val_accuracy: 0.9398
# Epoch 10/10
# 625/625 [==============================] - 295s 472ms/step - loss: 0.1149 - accuracy: 0.9536 - val_loss: 0.1481 - val_accuracy: 0.9420

# %%
plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
# /www.geeksforgeeks.org/choose-optimal-number-of-epochs-to-train-a-neural-network-in-keras/

# %%
#Fine Tuning

# %%
conv_base = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

conv_base.trainable = True

# %%
set_trainable = False

for layer in conv_base.layers:
  if layer.name == 'block5_conv1':
    set_trainable = True
  if set_trainable:
    layer.trainable = True
  else:
    layer.trainable = False

for layer in conv_base.layers:
  print(layer.name,layer.trainable)
# Out:
# input_4 False
# block1_conv1 False
# block1_conv2 False
# block1_pool False
# block2_conv1 False
# block2_conv2 False
# block2_pool False
# block3_conv1 False
# block3_conv2 False
# block3_conv3 False
# block3_pool False
# block4_conv1 False
# block4_conv2 False
# block4_conv3 False
# block4_pool False
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_pool True

# %%
model = Sequential()

model.add(conv_base)
model.add(Flatten())

model.add(Dense(256,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_6 (Flatten)         (None, 25088)             0
#
#  dense_17 (Dense)            (None, 256)               6422784
#
#  dense_18 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 21,137,729
# Trainable params: 13,502,465
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(train_ds,epochs=10,validation_data=validation_ds)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 126s 198ms/step - loss: 0.7209 - accuracy: 0.4960 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/10
# 625/625 [==============================] - 143s 229ms/step - loss: 0.6932 - accuracy: 0.4976 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/10
# 625/625 [==============================] - 144s 229ms/step - loss: 0.6932 - accuracy: 0.4928 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 4/10
# 625/625 [==============================] - 124s 197ms/step - loss: 0.6932 - accuracy: 0.4983 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/10
# 625/625 [==============================] - 123s 197ms/step - loss: 0.6932 - accuracy: 0.4974 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 6/10
# 625/625 [==============================] - 143s 228ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 7/10
# 625/625 [==============================] - 123s 197ms/step - loss: 0.6932 - accuracy: 0.4945 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 8/10
# 625/625 [==============================] - 124s 197ms/step - loss: 0.6932 - accuracy: 0.4944 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 9/10
# 625/625 [==============================] - 123s 196ms/step - loss: 0.6932 - accuracy: 0.4947 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 10/10
# 625/625 [==============================] - 124s 198ms/step - loss: 0.6932 - accuracy: 0.4960 - val_loss: 0.6932 - val_accuracy: 0.5000

# %%
plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()
