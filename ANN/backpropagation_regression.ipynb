# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa', 'profile_score', 'lpa'])
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameters(layer_dims):
  
    np.random.seed(3)
    parameters = {}
    L = len(layer_dims)         

    for l in range(1, L):

        parameters['W' + str(l)] = np.ones((layer_dims[l-1], layer_dims[l]))*0.1
        parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))

    return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev, W, b):
  
  Z = np.dot(W.T, A_prev) + b
  
  return Z

# %%
# Forward Prop
def L_layer_forward(X, parameters):

    A = X
    L = len(parameters) // 2                  # number of layers in the neural network

    for l in range(1, L+1):
        A_prev = A 
        Wl = parameters['W' + str(l)]
        bl = parameters['b' + str(l)]
        print("A"+str(l-1)+": ", A_prev)
        print("W"+str(l)+": ", Wl)
        print("b"+str(l)+": ", bl)
        print("--"*20)

        A = linear_forward(A_prev, Wl, bl)
        print("A"+str(l)+": ", A)
        print("**"*20)

    return A,A_prev

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X, parameters)
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************

# %%
y_hat = y_hat[0][0]

# %%
A1
# Out:
# array([[1.6],
#        [1.6]])

# %%
def update_parameters(parameters,y,y_hat,A1,X):
    parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat)*A1[0][0])
    parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat)*A1[1][0])
    parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat))

    parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
    parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
    parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])

    parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
    parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
    parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
update_parameters(parameters,y,y_hat,A1,X)

# %%
parameters
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.119136]])}

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.119136]])}

# %%
X = df[['cgpa', 'profile_score']].values[1].reshape(2,1) # Shape(no of features, no. of training exaplme)
y = df[['lpa']].values[1][0]

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[7]
#  [9]]
# W1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.00082267]]
# ----------------------------------------
# A1:  [[1.70612461]
#  [1.70612461]]
# ****************************************
# A1:  [[1.70612461]
#  [1.70612461]]
# W2:  [[0.111776]
#  [0.111776]]
# b2:  [[0.119136]]
# ----------------------------------------
# A2:  [[0.50054357]]
# ****************************************
# {'W1': array([[0.11458955, 0.1168776 ],
#         [0.11458955, 0.1168776 ]]),
#  'b1': array([[0.0019667],
#         [0.0019667]]),
#  'W2': array([[0.12712927],
#         [0.12712927]]),
#  'b2': array([[0.13612818]])}

# %%
X = df[['cgpa', 'profile_score']].values[2].reshape(2,1) # Shape(no of features, no. of training exaplme)
y = df[['lpa']].values[2][0]

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[ 6]
#  [10]]
# W1:  [[0.11458955 0.1168776 ]
#  [0.11458955 0.1168776 ]]
# b1:  [[0.0019667]
#  [0.0019667]]
# ----------------------------------------
# A1:  [[1.83539945]
#  [1.87200826]]
# ****************************************
# A1:  [[1.83539945]
#  [1.87200826]]
# W2:  [[0.12712927]
#  [0.12712927]]
# b2:  [[0.13612818]]
# ----------------------------------------
# A2:  [[0.6074482]]
# ****************************************
# {'W1': array([[0.12409711, 0.13272353],
#         [0.12412266, 0.13276611]]),
#  'b1': array([[0.00355129],
#         [0.00355555]]),
#  'W2': array([[0.14692424],
#         [0.14731907]]),
#  'b2': array([[0.15810417]])}

# %%
X = df[['cgpa', 'profile_score']].values[3].reshape(2,1) # Shape(no of features, no. of training exaplme)
y = df[['lpa']].values[3][0]

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[ 5]
#  [12]]
# W1:  [[0.12409711 0.13272353]
#  [0.12412266 0.13276611]]
# b1:  [[0.00355129]
#  [0.00355555]]
# ----------------------------------------
# A1:  [[2.11350869]
#  [2.26036654]]
# ****************************************
# A1:  [[2.11350869]
#  [2.26036654]]
# W2:  [[0.14692424]
#  [0.14731907]]
# b2:  [[0.15810417]]
# ----------------------------------------
# A2:  [[0.80162493]]
# ****************************************
# {'W1': array([[0.13482804, 0.15847776],
#         [0.1349909 , 0.15884991]]),
#  'b1': array([[0.00569748],
#         [0.0057292 ]]),
#  'W2': array([[0.17312488],
#         [0.17534027]]),
#  'b2': array([[0.18773702]])}

# %%
# epochs implementation

parameters = initialize_parameters([2,2,1])
epochs = 5

for i in range(epochs):

  Loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa', 'profile_score']].values[j].reshape(2,1) # Shape(no of features, no. of training example)
    y = df[['lpa']].values[j][0]

    # Parameter initialization


    y_hat,A1 = L_layer_forward(X,parameters)
    y_hat = y_hat[0][0]

    update_parameters(parameters,y,y_hat,A1,X)

    Loss.append((y-y_hat)**2)

    print('Epoch - ',i+1,'Loss - ',np.array(Loss).mean())

parameters
# Out:
# A0:  [[8]
#  [8]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************
# Epoch -  1 Loss -  13.542399999999997
# A0:  [[7]
#  [9]]
# W1:  [[0.10658137 0.10658137]
#  [0.10658137 0.10658137]]
# b1:  [[0.00082267]
#  [0.00082267]]
# ----------------------------------------
# A1:  [[1.70612461]
#  [1.70612461]]
# ****************************************
# A1:  [[1.70612461]
#  [1.70612461]]
# W2:  [[0.111776]
#  [0.111776]]
# b2:  [[0.119136]]
# ----------------------------------------
# A2:  [[0.50054357]]
# ****************************************
# Epoch -  1 Loss -  16.89375409265402
# A0:  [[ 6]
#  [10]]
# W1:  [[0.11458955 0.1168776 ]
#  [0.11458955 0.1168776 ]]
# b1:  [[0.0019667]
#  [0.0019667]]
# ----------------------------------------
# A1:  [[1.83539945]
#  [1.87200826]]
# ****************************************
# A1:  [[1.83539945]
#  [1.87200826]]
# W2:  [[0.12712927]
#  [0.12712927]]
# b2:  [[0.13612818]]
# ----------------------------------------
# A2:  [[0.6074482]]
# ****************************************
# Epoch -  1 Loss -  20.955707689548415
# A0:  [[ 5]
#  [12]]
# W1:  [[0.12409711 0.13272353]
#  [0.12412266 0.13276611]]
# b1:  [[0.00355129]
#  [0.00355555]]
# ----------------------------------------
# A1:  [[2.11350869]
#  [2.26036654]]
# ****************************************
# A1:  [[2.11350869]
#  [2.26036654]]
# W2:  [[0.14692424]
#  [0.14731907]]
# b2:  [[0.15810417]]
# ----------------------------------------
# A2:  [[0.80162493]]
# ****************************************
# Epoch -  1 Loss -  25.321744156025517
# A0:  [[8]
#  [8]]
# W1:  [[0.13482804 0.15847776]
#  [0.1349909  0.15884991]]
# b1:  [[0.00569748]
#  [0.0057292 ]]
# ----------------------------------------
# A1:  [[2.16424899]
#  [2.54435052]]
# ****************************************
# A1:  [[2.16424899]
#  [2.54435052]]
# W2:  [[0.17312488]
#  [0.17534027]]
# b2:  [[0.18773702]]
# ----------------------------------------
# A2:  [[1.00854947]]
# ****************************************
# Epoch -  2 Loss -  8.94877628927336
# A0:  [[7]
#  [9]]
# W1:  [[0.1437341  0.16738383]
#  [0.14411185 0.16797086]]
# b1:  [[0.00681073]
#  [0.00686932]]
# ----------------------------------------
# A1:  [[2.30995614]
#  [2.69029382]]
# ****************************************
# A1:  [[2.30995614]
#  [2.69029382]]
# W2:  [[0.18607337]
#  [0.19056287]]
# b2:  [[0.19654577]]
# ----------------------------------------
# A2:  [[1.13903718]]
# ****************************************
# Epoch -  2 Loss -  11.92790507630081
# A0:  [[ 6]
#  [10]]
# W1:  [[0.15475619 0.18155508]
#  [0.15553536 0.18265822]]
# b1:  [[0.00838532]
#  [0.00850125]]
# ----------------------------------------
# A1:  [[2.49227603]
#  [2.92441391]]
# ****************************************
# A1:  [[2.49227603]
#  [2.92441391]]
# W2:  [[0.20391068]
#  [0.21133712]]
# b2:  [[0.21905904]]
# ----------------------------------------
# A2:  [[1.34529793]]
# ****************************************
# Epoch -  2 Loss -  15.17402050192277
# A0:  [[ 5]
#  [12]]
# W1:  [[0.16744187 0.20269788]
#  [0.16886056 0.20486689]]
# b1:  [[0.0104996 ]
#  [0.01072211]]
# ----------------------------------------
# A1:  [[2.87403566]
#  [3.48261418]]
# ****************************************
# A1:  [[2.87403566]
#  [3.48261418]]
# W2:  [[0.22711228]
#  [0.23856167]]
# b2:  [[0.24787107]]
# ----------------------------------------
# A2:  [[1.73141811]]
# ****************************************
# Epoch -  2 Loss -  18.320004165722047
# A0:  [[8]
#  [8]]
# W1:  [[0.18100301 0.23524462]
#  [0.18336278 0.23967222]]
# b1:  [[0.01321183]
#  [0.01362256]]
# ----------------------------------------
# A1:  [[2.92813816]
#  [3.8129573 ]]
# ****************************************
# A1:  [[2.92813816]
#  [3.8129573 ]]
# W2:  [[0.25739647]
#  [0.27525854]]
# b2:  [[0.28579571]]
# ----------------------------------------
# A2:  [[2.08903719]]
# ****************************************
# Epoch -  3 Loss -  3.6517788658308783
# A0:  [[7]
#  [9]]
# W1:  [[0.18921518 0.24345679]
#  [0.1922245  0.24853394]]
# b1:  [[0.01423835]
#  [0.01473027]]
# ----------------------------------------
# A1:  [[3.06876509]
#  [3.95573325]]
# ****************************************
# A1:  [[3.06876509]
#  [3.95573325]]
# W2:  [[0.26858759]
#  [0.28983138]]
# b2:  [[0.29365331]]
# ----------------------------------------
# A2:  [[2.26438116]]
# ****************************************
# Epoch -  3 Loss -  5.567694642117171
# A0:  [[ 6]
#  [10]]
# W1:  [[0.20014476 0.25750911]
#  [0.20415354 0.26387128]]
# b1:  [[0.01579972]
#  [0.01643442]]
# ----------------------------------------
# A1:  [[3.25820367]
#  [4.20020184]]
# ****************************************
# A1:  [[3.25820367]
#  [4.20020184]]
# W2:  [[0.28537753]
#  [0.31147414]]
# b2:  [[0.31694538]]
# ----------------------------------------
# A2:  [[2.55501776]]
# ****************************************
# Epoch -  3 Loss -  7.667763981701261
# A0:  [[ 5]
#  [12]]
# W1:  [[0.21287024 0.27871824]
#  [0.21822616 0.28732564]]
# b1:  [[0.01792063]
#  [0.01877986]]
# ----------------------------------------
# A1:  [[3.7009857 ]
#  [4.86027872]]
# ****************************************
# A1:  [[3.7009857 ]
#  [4.86027872]]
# W2:  [[0.30782644]
#  [0.34041338]]
# b2:  [[0.34730334]]
# ----------------------------------------
# A2:  [[3.14106851]]
# ****************************************
# Epoch -  3 Loss -  9.473661050729628
# A0:  [[8]
#  [8]]
# W1:  [[0.22585131 0.3098728 ]
#  [0.23281    0.32232686]]
# b1:  [[0.02051684]
#  [0.02169662]]
# ----------------------------------------
# A1:  [[3.68980727]
#  [5.07929387]]
# ****************************************
# A1:  [[3.68980727]
#  [5.07929387]]
# W2:  [[0.33639014]
#  [0.37792434]]
# b2:  [[0.38564221]]
# ----------------------------------------
# A2:  [[3.54644581]]
# ****************************************
# Epoch -  4 Loss -  0.20571140374584412
# A0:  [[7]
#  [9]]
# W1:  [[0.22831673 0.31233823]
#  [0.23558598 0.32510284]]
# b1:  [[0.02082502]
#  [0.02204362]]
# ----------------------------------------
# A1:  [[3.73931597]
#  [5.13433676]]
# ****************************************
# A1:  [[3.73931597]
#  [5.13433676]]
# W2:  [[0.3397372 ]
#  [0.38253181]]
# b2:  [[0.38343892]]
# ----------------------------------------
# A2:  [[3.61787081]]
# ****************************************
# Epoch -  4 Loss -  1.057996245285437
# A0:  [[ 6]
#  [10]]
# W1:  [[0.23509059 0.32104747]
#  [0.24326252 0.33497268]]
# b1:  [[0.02179271]
#  [0.02314027]]
# ----------------------------------------
# A1:  [[3.86496148]
#  [5.2991519 ]]
# ****************************************
# A1:  [[3.86496148]
#  [5.2991519 ]]
# W2:  [[0.35007363]
#  [0.39672445]]
# b2:  [[0.39948871]]
# ----------------------------------------
# A2:  [[3.85481293]]
# ****************************************
# Epoch -  4 Loss -  2.2392733546195394
# A0:  [[ 5]
#  [12]]
# W1:  [[0.24452913 0.33677838]
#  [0.25406036 0.35296907]]
# b1:  [[0.02336581]
#  [0.02493991]]
# ----------------------------------------
# A1:  [[4.29473577]
#  [5.94446068]]
# ****************************************
# A1:  [[4.29473577]
#  [5.94446068]]
# W2:  [[0.36665576]
#  [0.41945979]]
# b2:  [[0.42375017]]
# ----------------------------------------
# A2:  [[4.49190204]]
# ****************************************
# Epoch -  4 Loss -  3.2520938634031613
# A0:  [[8]
#  [8]]
# W1:  [[0.25426555 0.36014576]
#  [0.2653287  0.38001309]]
# b1:  [[0.02531309]
#  [0.02719358]]
# ----------------------------------------
# A1:  [[4.18206705]
#  [5.94846444]]
# ****************************************
# A1:  [[4.18206705]
#  [5.94846444]]
# W2:  [[0.388199  ]
#  [0.44927837]]
# b2:  [[0.45429457]]
# ----------------------------------------
# A2:  [[4.75028523]]
# ****************************************
# Epoch -  5 Loss -  0.5629279313986889
# A0:  [[7]
#  [9]]
# W1:  [[0.24968072 0.35556094]
#  [0.26004246 0.37472686]]
# b1:  [[0.02473998]
#  [0.0265328 ]]
# ----------------------------------------
# A1:  [[4.11288719]
#  [5.88800108]]
# ****************************************
# A1:  [[4.11288719]
#  [5.88800108]]
# W2:  [[0.38192351]
#  [0.44035228]]
# b2:  [[0.43885171]]
# ----------------------------------------
# A2:  [[4.60245475]]
# ****************************************
# Epoch -  5 Loss -  0.36048507822026327
# A0:  [[ 6]
#  [10]]
# W1:  [[0.25182457 0.35831731]
#  [0.26251936 0.37791144]]
# b1:  [[0.02504625]
#  [0.02688664]]
# ----------------------------------------
# A1:  [[4.16118723]
#  [5.95590488]]
# ****************************************
# A1:  [[4.16118723]
#  [5.95590488]]
# W2:  [[0.38519363]
#  [0.44503378]]
# b2:  [[0.44582887]]
# ----------------------------------------
# A2:  [[4.69927052]]
# ****************************************
# Epoch -  5 Loss -  0.804289112779833
# A0:  [[ 5]
#  [12]]
# W1:  [[0.25800593 0.36861958]
#  [0.26970762 0.38989188]]
# b1:  [[0.02607647]
#  [0.02808469]]
# ----------------------------------------
# A1:  [[4.55259758]
#  [6.54988512]]
# ****************************************
# A1:  [[4.55259758]
#  [6.54988512]]
# W2:  [[0.39601879]
#  [0.46052782]]
# b2:  [[0.46312928]]
# ----------------------------------------
# A2:  [[5.28244776]]
# ****************************************
# Epoch -  5 Loss -  1.3407132589299962
# {'W1': array([[0.26507636, 0.38558861],
#         [0.27800387, 0.40980287]]),
#  'b1': array([[0.02749056],
#         [0.02974394]]),
#  'W2': array([[0.41165744],
#         [0.48302736]]),
#  'b2': array([[0.48646246]])}

# %%
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2,activation='linear',input_dim=2))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 2)                 6
#
#  dense_3 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[ 0.91126263, -1.1656781 ],
#         [-0.24168706,  0.6082994 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.33838487],
#         [ 0.78165686]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
new_weights = [np.array([[ 0.1, 0.1 ],
        [ 0.1,  0.1 ]], dtype=np.float32),
 np.array([0., 0.], dtype=np.float32),
 np.array([[0.1],
        [ 0.1]], dtype=np.float32),
 np.array([0.], dtype=np.float32)]

# %%
model.set_weights(new_weights)

# %%
model.get_weights()
# Out:
# [array([[0.1, 0.1],
#         [0.1, 0.1]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.1],
#         [0.1]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
model.compile(loss='mean_squared_error',optimizer=keras.optimizers.Adam(learning_rate=0.001))

# %%
model.fit(df.iloc[:,:-1],df.iloc[:,-1],epochs=75,verbose=1,batch_size=1)
# Out:
# Epoch 1/75
# 4/4 [==============================] - 2s 3ms/step - loss: 27.9165
# Epoch 2/75
# 4/4 [==============================] - 0s 3ms/step - loss: 27.5780
# Epoch 3/75
# 4/4 [==============================] - 0s 3ms/step - loss: 27.2713
# Epoch 4/75
# 4/4 [==============================] - 0s 3ms/step - loss: 26.9174
# Epoch 5/75
# 4/4 [==============================] - 0s 5ms/step - loss: 26.5560
# Epoch 6/75
# 4/4 [==============================] - 0s 3ms/step - loss: 26.2056
# Epoch 7/75
# 4/4 [==============================] - 0s 2ms/step - loss: 25.8567
# Epoch 8/75
# 4/4 [==============================] - 0s 3ms/step - loss: 25.4741
# Epoch 9/75
# 4/4 [==============================] - 0s 2ms/step - loss: 25.0618
# Epoch 10/75
# 4/4 [==============================] - 0s 2ms/step - loss: 24.6500
# Epoch 11/75
# 4/4 [==============================] - 0s 3ms/step - loss: 24.2685
# Epoch 12/75
# 4/4 [==============================] - 0s 3ms/step - loss: 23.8114
# Epoch 13/75
# 4/4 [==============================] - 0s 3ms/step - loss: 23.4104
# Epoch 14/75
# 4/4 [==============================] - 0s 3ms/step - loss: 22.9266
# Epoch 15/75
# 4/4 [==============================] - 0s 2ms/step - loss: 22.4848
# Epoch 16/75
# 4/4 [==============================] - 0s 2ms/step - loss: 22.0305
# Epoch 17/75
# 4/4 [==============================] - 0s 2ms/step - loss: 21.5706
# Epoch 18/75
# 4/4 [==============================] - 0s 2ms/step - loss: 21.0717
# Epoch 19/75
# 4/4 [==============================] - 0s 3ms/step - loss: 20.5562
# Epoch 20/75
# 4/4 [==============================] - 0s 3ms/step - loss: 20.0725
# Epoch 21/75
# 4/4 [==============================] - 0s 2ms/step - loss: 19.5886
# Epoch 22/75
# 4/4 [==============================] - 0s 3ms/step - loss: 19.0910
# Epoch 23/75
# 4/4 [==============================] - 0s 2ms/step - loss: 18.5470
# Epoch 24/75
# 4/4 [==============================] - 0s 2ms/step - loss: 18.0250
# Epoch 25/75
# 4/4 [==============================] - 0s 2ms/step - loss: 17.4945
# Epoch 26/75
# 4/4 [==============================] - 0s 2ms/step - loss: 17.0340
# Epoch 27/75
# 4/4 [==============================] - 0s 3ms/step - loss: 16.4392
# Epoch 28/75
# 4/4 [==============================] - 0s 2ms/step - loss: 15.9547
# Epoch 29/75
# 4/4 [==============================] - 0s 3ms/step - loss: 15.3845
# Epoch 30/75
# 4/4 [==============================] - 0s 3ms/step - loss: 14.8688
# Epoch 31/75
# 4/4 [==============================] - 0s 2ms/step - loss: 14.4092
# Epoch 32/75
# 4/4 [==============================] - 0s 2ms/step - loss: 13.8737
# Epoch 33/75
# 4/4 [==============================] - 0s 3ms/step - loss: 13.3383
# Epoch 34/75
# 4/4 [==============================] - 0s 1ms/step - loss: 12.7615
# Epoch 35/75
# 4/4 [==============================] - 0s 2ms/step - loss: 12.3249
# Epoch 36/75
# 4/4 [==============================] - 0s 2ms/step - loss: 11.8433
# Epoch 37/75
# 4/4 [==============================] - 0s 2ms/step - loss: 11.3058
# Epoch 38/75
# 4/4 [==============================] - 0s 2ms/step - loss: 10.8463
# Epoch 39/75
# 4/4 [==============================] - 0s 2ms/step - loss: 10.2997
# Epoch 40/75
# 4/4 [==============================] - 0s 2ms/step - loss: 9.9050
# Epoch 41/75
# 4/4 [==============================] - 0s 3ms/step - loss: 9.3837
# Epoch 42/75
# 4/4 [==============================] - 0s 2ms/step - loss: 8.9487
# Epoch 43/75
# 4/4 [==============================] - 0s 2ms/step - loss: 8.5969
# Epoch 44/75
# 4/4 [==============================] - 0s 3ms/step - loss: 8.1372
# Epoch 45/75
# 4/4 [==============================] - 0s 4ms/step - loss: 7.7109
# Epoch 46/75
# 4/4 [==============================] - 0s 2ms/step - loss: 7.3299
# Epoch 47/75
# 4/4 [==============================] - 0s 3ms/step - loss: 6.8757
# Epoch 48/75
# 4/4 [==============================] - 0s 2ms/step - loss: 6.5450
# Epoch 49/75
# 4/4 [==============================] - 0s 2ms/step - loss: 6.1584
# Epoch 50/75
# 4/4 [==============================] - 0s 1ms/step - loss: 5.8410
# Epoch 51/75
# 4/4 [==============================] - 0s 3ms/step - loss: 5.5372
# Epoch 52/75
# 4/4 [==============================] - 0s 3ms/step - loss: 5.2267
# Epoch 53/75
# 4/4 [==============================] - 0s 3ms/step - loss: 4.8974
# Epoch 54/75
# 4/4 [==============================] - 0s 2ms/step - loss: 4.6447
# Epoch 55/75
# 4/4 [==============================] - 0s 3ms/step - loss: 4.3379
# Epoch 56/75
# 4/4 [==============================] - 0s 2ms/step - loss: 4.1294
# Epoch 57/75
# 4/4 [==============================] - 0s 3ms/step - loss: 3.8630
# Epoch 58/75
# 4/4 [==============================] - 0s 2ms/step - loss: 3.6307
# Epoch 59/75
# 4/4 [==============================] - 0s 2ms/step - loss: 3.4091
# Epoch 60/75
# 4/4 [==============================] - 0s 2ms/step - loss: 3.2345
# Epoch 61/75
# 4/4 [==============================] - 0s 2ms/step - loss: 3.0328
# Epoch 62/75
# 4/4 [==============================] - 0s 2ms/step - loss: 2.8365
# Epoch 63/75
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6678
# Epoch 64/75
# 4/4 [==============================] - 0s 2ms/step - loss: 2.5239
# Epoch 65/75
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3881
# Epoch 66/75
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2973
# Epoch 67/75
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1254
# Epoch 68/75
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0470
# Epoch 69/75
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9208
# Epoch 70/75
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8479
# Epoch 71/75
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7455
# Epoch 72/75
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6856
# Epoch 73/75
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6237
# Epoch 74/75
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5485
# Epoch 75/75
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5187

# %%
model.get_weights()
# Out:
# [array([[0.37373924, 0.37373924],
#         [0.3656012 , 0.3656012 ]], dtype=float32),
#  array([0.27236295, 0.27236295], dtype=float32),
#  array([[0.37296113],
#         [0.37296113]], dtype=float32),
#  array([0.20470694], dtype=float32)]
